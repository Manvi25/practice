# %%
# Read JSON file from DBFS
parquet_df = spark.read.json("/user/hive/warehouse/life_expectancy_data_csv/part-00000-tid-2768621510955662498-2ebc38b1-9efd-4868-a36e-f1af8c5b0464-55-1-c000.snappy.parquet")

# Show the DataFrame
parquet_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# 2.7�3i12�
